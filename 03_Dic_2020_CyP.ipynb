# %% [markdown]
# <a href="https://colab.research.google.com/github/PBarley/cyp_2021/blob/main/03_Dic_2020_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EJMEPLO 1

for i in [1,2,3,4,5]: 
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 4
# El elemento: 5

# %%
#EJMEPLO 1.1

coleccion = [1,2,3,4,5]
for i in coleccion: 
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 4
# El elemento: 5

# %%
#EJEMPLO 2

coleccion={"Mario":20, "Mariana": 19, "Yessica":14, "Luis":18}
for i in coleccion:
  print(f"Elemento: {i}")
# Out:
# Elemento: Mario
# Elemento: Mariana
# Elemento: Yessica
# Elemento: Luis

# %%
#EJEMPLO 2.1

coleccion={"Mario":20, "Mariana": 19, "Yessica":14, "Luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
#EJEMPLO 2.2

coleccion={"Mario":20, "Mariana": 19, "Yessica":14, "Luis":18}
for i in coleccion:
  print(f"{i}-> {coleccion [i]}")
# Out:
# Mario-> 20
# Mariana-> 19
# Yessica-> 14
# Luis-> 18

# %%
coleccion={"Mario":20, "Mariana": 19, "Yessica":14, "Luis":18}

#Usamos item: ayuda a recorrer lo que hay dentro de una colección. Muy usado al usar FOR.
for clave, valor in coleccion. items ():
  print (f"{clave} -> {valor}")
# Out:
# Mario -> 20
# Mariana -> 19
# Yessica -> 14
# Luis -> 18

# %%
#EJEMPLO 3

#Queremos saber si es un email
email=False
for i in "ariel@unam.mx":
  #Doble == es para comparación
  if (i == "@"):
    email= True 
if email== True:
  print("El email es correcto")
else:
  print("El correo es incorrecto")
# Out:
# El email es correcto

# %%
#EJEMPLO 3.1

miEmail=input("Introduce tu correo electroico")

for i in miEmail:
  #Doble == es para comparación
  if (i == "@"):
    email= True 

if email:
  print("El email es correcto")
else:
  print("El correo es incorrecto")

# %%
#For - Range

for i in range (5):
  print("Hola Mundo")
# Out:
# Hola Mundo
# Hola Mundo
# Hola Mundo
# Hola Mundo
# Hola Mundo

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (20):
  print(f"Valor de la variable {i}")
# Out:
# Valor de la variable 0
# Valor de la variable 1
# Valor de la variable 2
# Valor de la variable 3
# Valor de la variable 4
# Valor de la variable 5
# Valor de la variable 6
# Valor de la variable 7
# Valor de la variable 8
# Valor de la variable 9
# Valor de la variable 10
# Valor de la variable 11
# Valor de la variable 12
# Valor de la variable 13
# Valor de la variable 14
# Valor de la variable 15
# Valor de la variable 16
# Valor de la variable 17
# Valor de la variable 18
# Valor de la variable 19

# %%
# WHILE EJEMPLOS

#EJEMPLO 1

i= 1
# Necesita un + 1 para romper el bucle infinito
while 1<=10:
  print("Ejecución" + str (i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# ...

# %%
# EJEMPLO 2, WHILE.

i=1

while i<=10:
  print("Ejecución"+ str (i))

  i= i + 1 #Contador, es decir, incrementa en 1 la variable
# Out:
# Ejecución1
# Ejecución2
# Ejecución3
# Ejecución4
# Ejecución5
# Ejecución6
# Ejecución7
# Ejecución8
# Ejecución9
# Ejecución10

# %%
# EJEMPLO 3, WHILE

edad= int (input("Introduce tu edad: "))
while edad < 0:
  print ("Has introducido una edad negativa, intental de nuevo")
  edad= int (input("Introduce tu edad: "))
print("Gracias por participar. Puede pasar")
print("Edad del aspirantes " + str(edad))
# Out:
# Introduce tu edad: 20
# Gracias por participar. Puede pasar
# Edad del aspirantes 20

# %%
# EJEMPLO 4, WHILE

edad= int (input("Introduce tu edad: "))
while edad < 0 or edad >101:
  print ("Has introducido una edad negativa, intental de nuevo")
  edad= int (input("Introduce tu edad: "))
print("Gracias por participar. Puede pasar")
print("Edad del aspirantes " + str(edad))
# Out:
# Introduce tu edad: 100
# Gracias por participar. Puede pasar
# Edad del aspirantes 100
